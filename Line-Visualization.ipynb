# %%
import BackendFunction as bf

# %% [markdown]
# ## Read chat history.

# %%
# Input your chat_name.txt
chatName = '[LINE] Chat with someone.txt'
chat_data = bf.OpenFile(chatName)

# %%
chat_data
# Out:
#        Day        Date   Time  User  \
# 0      Fri  25/08/2017  19:34    P🎈
# 1      Fri  25/08/2017  19:34    P🎈
# 2      Fri  25/08/2017  19:51  indy
# 3      Fri  25/08/2017  19:55    P🎈
# 4      Sat  26/08/2017  18:24    P🎈
# ...    ...         ...    ...   ...
# 18536  Sat  15/12/2018  14:29  indy
# 18537  Sat  15/12/2018  14:30  indy
# 18538  Sat  15/12/2018  14:31    P🎈
# 18539  Sat  15/12/2018  14:31    P🎈
# 18540  Sat  15/12/2018  14:48  indy
#
#                                                 Messages            DateTime  \
# 0                                               พรุ่งนี้ 2017-08-25 19:34:00
# 1                                              9 โมงนะคะ 2017-08-25 19:34:00
# 2                                              โอเคครับบ 2017-08-25 19:51:00
# 3                                     เดียว จะประชุมก่อน 2017-08-25 19:55:00
# 4                                       ☎ Call time 5:13 2017-08-26 18:24:00
# ...                                                  ...                 ...
# 18536                                  the beauty inside 2018-12-15 14:29:00
# 18537                        เรื่องนี้ที่นางเอกซื้อรถให้ 2018-12-15 14:30:00
# 18538                                         กูได้นานละ 2018-12-15 14:31:00
# 18539                                           55555555 2018-12-15 14:31:00
# 18540  ดูมาละมาละมาบอกด้วยว่าหนุกป่าวถ้าหนุกจะไปดู555555 2018-12-15 14:48:00
#
#        Group  MessageTime
# 0      19-20         1174
# 1      19-20         1174
# 2      19-20         1191
# 3      19-20         1195
# 4      18-19         1104
# ...      ...          ...
# 18536  14-15          869
# 18537  14-15          870
# 18538  14-15          871
# 18539  14-15          871
# 18540  14-15          888
#
# [18541 rows x 8 columns]

# %%
chat = bf.ReadChat(chatName)
chat = bf.ChatRestr(chat)

# %%
chat[0]
# Out:
# ['Fri', '25/08/2560', '19:34', 'P🎈', 'พรุ่งนี้']

# %%
import re

# %%
for i in range(len(testdata)):
    if re.search("^[M, T, W, T, F, S]..,", testdata[i]):
        print('Match',  print(testdata[i]))
# Out:
# Mon, 22/07/2562
# Match None
# Tue, 06/08/2562
# Match None
# Sun, 18/08/2562
# Match None
# Mon, 19/08/2562
# Match None
# Wed, 21/08/2562
# Match None

# %% [markdown]
# ----------

# %% [markdown]
# ## Visualization

# %%
# Plot summary information [All time]
bf.summaryInformation(chat_data)
# Out:
# ------------------------------------------------------------------------------------------------------------
#                               Plot result from data (25/08/2017 - 15/12/2018)
# ------------------------------------------------------------------------------------------------------------
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Plot number of conversations for each user by month
bf.TrendPlot(chat_data, 'Monthly')
# Out:
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Show avalible chat history date.
bf.availableDay(chat_data)
# Out:
# {'2017/08',
#  '2017/09',
#  '2017/10',
#  '2017/11',
#  '2017/12',
#  '2018/01',
#  '2018/02',
#  '2018/03',
#  '2018/04',
#  '2018/05',
#  '2018/06',
#  '2018/07',
#  '2018/08',
#  '2018/09',
#  '2018/10',
#  '2018/11',
#  '2018/12'}

# %%
# Input specific year and month for data filter.
year = int(input("Please input Year : "))
month = int(input("Please input Month Number : "))
filtered_data = bf.dateFilter(data=chat_data, month=month, year=year)
# Out:
# Please input Year :  2019
# Please input Month Number :  1

# %%
# Plot number of conversations for each user by days.
bf.TrendPlot(filtered_data, method='Daily')
# Out:
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Plot histogram respond each user
bf.respondHist((filtered_data), brange=60)
# Out:
# User : indy
# Average respond time : 11.67 minute
# Min respond time = 0 minute
# User : ppin🎈
# Average respond time : 15.15 minute
# Min respond time = 0 minute

# %%
# Plot heatmap
bf.plotHeatmap(filtered_data)

# %%
# Plot number of conversations for each user by weekday
bf.TrendPlot(filtered_data, method='Hourly')
# Out:
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
bf.TrendPlot(filtered_data, method='Weekly')
# Out:
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\INDY\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 57224 missing from current font.
#   font.set_text(s, 0, flags=flags)
